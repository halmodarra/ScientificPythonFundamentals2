# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns 

import plotly.express as px
import plotly.graph_objects as go
from jupyter_dash import JupyterDash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
from datetime import date

# %%
#df = pd.read_csv('/Users/halmodarra/Downloads/bollywood_full.csv')
df = pd.read_csv('/Users/halmodarra/Downloads/friends_info.csv')
df = pd.read_csv('/Users/halmodarra/Downloads/hotel_bookings.csv')

#/Users/halmodarra/Downloads/hotel_bookings.csv



df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
app = JupyterDash(__name__)

app.layout = html.Div([
    html.Label('Hotel Type'),
   dcc.Dropdown(
    options=[
        {'label': 'Resort Hotel', 'value': 'Resort Hotel'},
        {'label': 'City Hotel', 'value': 'City Hotel'}
    ],
    value='Resort Hotel'
), 
    html.Label('Date Range'),
    dcc.DatePickerRange(
        month_format='MMM Do, YY',
        end_date_placeholder_text='MMM Do, YY',
        start_date=date(2015,7,1)
    )  
    
])

if __name__ == '__main__':
    app.run_server(debug=True, port=8051)
# Out:
# Dash app running on http://127.0.0.1:8051/

# %%
# App layout
app.layout = html.Div([

    html.H1("Friends", style={'text-align': 'center'}),

    dcc.Dropdown(id="slct_episode",
                 options=[
                     {"label": "01-01", "value": 2015},
                     {"label": "2016", "value": 2016},
                     {"label": "2017", "value": 2017},
                     {"label": "2018", "value": 2018}],
                 multi=False,
                 value=2015,
                 style={'width': "40%"}
                 ),
    
    html.Br(),
    
    dcc.Dropdown(id="slct_affected",
                 options=[
                     {"label": "Pesticides", "value": "Pesticides"},
                     {"label": "Disease", "value": "Disease"},
                     {"label": "Pests_excl_Varroa", "value": "Pests_excl_Varroa"},
                     {"label": "Other", "value": "Other"},
                     {"label": "Unknown", "value": "Unknown"},
                     {"label": "Varroa_mites", "value": "Varroa_mites"}],
                 multi=False,
                 value="Pesticides",
                 style={'width': "40%"}
                 ),
    
    html.Br(),
    html.Div(id='output_container', children=[]),
    html.Br(),

    dcc.Graph(id='my_bee_map', figure={})

])

@app.callback(
    [Output(component_id='output_container', component_property='children'),
     Output(component_id='my_bee_map', component_property='figure')],
    [Input(component_id='slct_year', component_property='value'),
    Input(component_id='slct_affected', component_property='value')]
)

def update_graph(option_slctd, option_affected):
    
    # These are for the selection from the dropdown list "our only input"
    print(option_slctd)
    print(option_affected)
    print(type(option_slctd))
    print(type(option_affected))

    container = "The year chosen by user was: {}".format(option_slctd)

    dff = df.copy()
    dff = dff[dff["Year"] == option_slctd]
    dff = dff[dff["Affected by"] == option_affected]

    # Plotly Express
    fig = px.choropleth(
        data_frame=dff,
        locationmode='USA-states',
        locations='state_code',
        scope="usa",
        color='Pct of Colonies Impacted',
        hover_data=['State', 'Pct of Colonies Impacted'],
        color_continuous_scale=px.colors.sequential.YlOrRd,
        labels={'Pct of Colonies Impacted': '% of Bee Colonies'},
        template='plotly_dark'
    )

    # Plotly Graph Objects (GO)
    # fig = go.Figure(
    #     data=[go.Choropleth(
    #         locationmode='USA-states',
    #         locations=dff['state_code'],
    #         z=dff["Pct of Colonies Impacted"].astype(float),
    #         colorscale='Reds',
    #     )]
    # )
    #
    # fig.update_layout(
    #     title_text="Bees Affected by Mites in the USA",
    #     title_xanchor="center",
    #     title_font=dict(size=24),
    #     title_x=0.5,
    #     geo=dict(scope='usa'),
    # )

    return container, fig

# ------------------------------------------------------------------------------
if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-5cae323f5f6e> in <module>
#       1 # App layout
# ----> 2 app.layout = html.Div([
#       3
#       4     html.H1("Friends", style={'text-align': 'center'}),
#       5
#
# NameError: name 'app' is not defined
